# %% [markdown]
# <a href="https://colab.research.google.com/github/khupkhaidopmul-stack/lis4693/blob/main/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

import requests

url = "https://raw.githubusercontent.com/khupkhaidopmul-stack/lis4693/refs/heads/main/lab-1/transcript.txt"
response = requests.get(url)
response.raise_for_status() # Raise an exception for HTTP errors
text = response.text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
print("Number of characters:", len(text)) # print number of characters

print(text[:100])   # print first 100 characters
# Out:
# Number of characters: 5399
# The puck is down at Milano
# ice hockey arena,
# Finland and Switzerland,
# underway on day four.
# Karvinen

# %%
nlp = spacy.blank("en")
nlp.add_pipe("sentencizer")

doc = nlp(text)

sentences = list(doc.sents)

print("Number of sentences:", len(sentences))

print("\nFirst 3 sentences:")
for sent in sentences[:3]:
    print(sent)
# Out:
# Number of sentences: 107
#
# First 3 sentences:
# The puck is down at Milano
# ice hockey arena,
# Finland and Switzerland,
# underway on day four.
#
# Karvinen tried a jab and out
# front, but it is Mueller.
#
# Mueller dispossessed
# by kuoppala.

# %%
words = [token.text.lower() for token in doc if token.is_alpha]

print("Total words:", len(words))
print("Unique words:", len(set(words)))
# Out:
# Total words: 990
# Unique words: 354

# %%
from collections import Counter

word_freq = Counter(words)

print("Top most frequent words:")
for word, count in word_freq.most_common(1):
    print(word, count)
# Out:
# Top most frequent words:
# the 68

# %%
nlp2 = spacy.load("en_core_web_sm")

doc2 = nlp2(text)

print("Named Entities:")
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# Named Entities:
# Milano ORG
# Finland GPE
# Switzerland GPE
# day four DATE
# Karvinen PERSON
# Mueller PERSON
# Mueller PERSON
# kuoppala PERSON
# Kuoppala PERSON
# Zain
# Gray PERSON
# Ahola ORG
# Toulouse PERSON
# Ahola ORG
# maruk
# hertzig ORG
# Switzerland GPE
# rasila PERSON
# Verhaeghe ORG
# rantala GPE
# Mauer PERSON
# Van de Toulouse PERSON
# Newton GPE
# Newton GPE
# Diamond ORG
# Müller PERSON
# Valerio PERSON
# Newton GPE
# Newton GPE
# Meyer ORG
# Newton GPE
# Newton GPE
# Toulouse PERSON
# Meyer ORG
# Anik ORG
# Böckler PERSON
# three CARDINAL
# two CARDINAL
# Myra PERSON
# Mark PERSON
# Nieminen PERSON
# 2 CARDINAL
# Milano ORG
# Switzerland GPE
# Finland GPE
# Ahola GPE
# Vanek ORG
# Kissed PERSON
# Maurer GPE
# first ORDINAL
# Veronica GPE
# Finland GPE
# Finland GPE
# first ORDINAL
# Milano Cortina ORG
# 2026 DATE
# Vanhanen GPE
# five CARDINAL
# Ma PERSON
# Finland GPE
# Green PERSON
# MacKinnon ORG
# Marr PERSON
# Newton GPE
# Siegrist NORP
# Kneeling PERSON
# ...

# %%
from spacy.matcher import PhraseMatcher

matcher = PhraseMatcher(nlp2.vocab, attr="LOWER")

phrases = ["united states", "america", "country"]

patterns = [nlp2(p) for p in phrases]

matcher.add("TECH_TERMS", patterns)

matches = matcher(doc2)

print("Matches found:")
for match_id, start, end in matches:
    print(doc2[start:end])
    print("Sentence:", doc2[start].sent)
# Out:
# Matches found:

# %% [markdown]
# Overall, this assignment went well because I was able to successfully implement the required features and understand how each part of the code worked together. I felt more comfortable navigating Google Colab and organizing my notebook with both code and text cells. Testing the code step-by-step helped me identify errors quickly and better understand the logic behind the implementation.
#
# One challenge I encountered was debugging errors when the code did not run as expected. At times, small syntax mistakes or incorrect variable usage caused issues that took time to identify. Additionally, understanding certain concepts initially required reviewing notes and examples. However, working through these challenges helped strengthen my problem-solving skills and improved my confidence in using Python and Colab.
